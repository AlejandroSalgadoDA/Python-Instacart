# %% [markdown]
# # Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
path = r'/Users/alejandrosalgado/Desktop/Instacart Basket Analysis'

# %%
orders_products_combined = pd.read_pickle(r'/Users/alejandrosalgado/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_combined.pkl')

# %% [markdown]
# # Task 4.6

# %%
# checking shape
orders_products_combined.shape
# Out:
# (32434489, 13)

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  customer_id  order_number  \
# 0             0           0   2539329            1             1
# 1             0           0   2539329            1             1
# 2             0           0   2539329            1             1
# 3             0           0   2539329            1             1
# 4             0           0   2539329            1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   2                  8                     NaN
# 2                   2                  8                     NaN
# 3                   2                  8                     NaN
# 4                   2                  8                     NaN
#
#    new_customer  product_id  add_to_cart_order  reordered _merge
# 0          True         196                  1          0   both
# ...

# %%
# import products dataset
df_prods=  pd.read_csv(r'/Users/alejandrosalgado/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/products_cleaned.csv', index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
# removing '_merge' column 
orders_products_combined = orders_products_combined.drop(columns = ['_merge'])

# %%
# merging products and orders data frames
df_orders_products_merged = orders_products_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  customer_id  order_number  \
# 0             0             0   2539329            1             1
# 1             1             1   2398795            1             2
# 2             2             2    473747            1             3
# 3             3             3   2254736            1             4
# 4             4             4    431534            1             5
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# 1                   3                  7                    15.0
# 2                   3                 12                    21.0
# 3                   4                  7                    29.0
# 4                   4                 15                    28.0
#
#    new_customer  product_id  add_to_cart_order  reordered  Unnamed: 0_y  \
# 0          True         196                  1          0           195
# ...

# %%
# drop unnecessary columns 
df_orders_products_merged = df_orders_products_merged.drop(columns = ['Unnamed: 0.1','Unnamed: 0_x'])

# %%
df_orders_products_merged.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
# checking merge flag of merged data frame
df_orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# checking shape
df_orders_products_merged.shape
# Out:
# (32404859, 16)

# %% [markdown]
# # Export data

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
