# %% [markdown]
# # Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
path = r'/Users/alejandrosalgado/Desktop/Instacart Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(r'/Users/alejandrosalgado/Desktop/Instacart Basket Analysis/02 Data/Prepared Data/orders_products_merged_v3.pkl')

# %%
df = ords_prods_merge

# %%
df.shape
# Out:
# (32404859, 22)

# %%
df.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
# Find the mean of orders by department id
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# This is the mean for all the department_ids in the dataset as opposed to the first one million rows. The dataset that shows one milliion rows is a smaller dataset and is not as accurate as the complete dataset.

# %%
# create a loyalty flag
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['customer_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2539329            1             1                   2
# 1    2398795            1             2                   3
# 2     473747            1             3                   3
# 3    2254736            1             4                   4
# 4     431534            1             5                   4
# 5    3367565            1             6                   2
# 6     550135            1             7                   1
# 7    3108588            1             8                   1
# 8    2295261            1             9                   1
# 9    2550362            1            10                   4
# 10   2968173           15            15                   1
# 11   1870022           15            17                   2
# 12   1911383           15            18                   2
# 13   2715276           15            21                   1
# 14    487368           15            22                   1
#
# ...

# %%
# create loyalty flag with parameters
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
# Count number of customers by loyalty flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['customer_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     customer_id      loyalty_flag  order_number
# 0             1      New customer             1
# 1             1      New customer             2
# 2             1      New customer             3
# 3             1      New customer             4
# 4             1      New customer             5
# 5             1      New customer             6
# 6             1      New customer             7
# 7             1      New customer             8
# 8             1      New customer             9
# 9             1      New customer            10
# 10           15  Regular customer            15
# 11           15  Regular customer            17
# 12           15  Regular customer            18
# 13           15  Regular customer            21
# 14           15  Regular customer            22
# 15           19      New customer             2
# 16           19      New customer             5
# 17           19      New customer             7
# 18           21  Regular customer            10
# ...

# %%
# check the mean min max  
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean','min','max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %%
# transform prices to see the average price
ords_prods_merge['average_price']= ords_prods_merge.groupby(['customer_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(60)
# Out:
#     order_id  customer_id  order_number  orders_day_of_week  \
# 0    2539329            1             1                   2
# 1    2398795            1             2                   3
# 2     473747            1             3                   3
# 3    2254736            1             4                   4
# 4     431534            1             5                   4
# 5    3367565            1             6                   2
# 6     550135            1             7                   1
# 7    3108588            1             8                   1
# 8    2295261            1             9                   1
# 9    2550362            1            10                   4
# 10   2968173           15            15                   1
# 11   1870022           15            17                   2
# 12   1911383           15            18                   2
# 13   2715276           15            21                   1
# 14    487368           15            22                   1
# ...

# %%
# create new columns 
ords_prods_merge.loc[ords_prods_merge['average_price']<10, 'spending_flag']= 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_price']>=10, 'spending_flag']= 'High spender'

# %%
ords_prods_merge['spending_flag'].value_counts(dropna=False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
ords_prods_merge[['customer_id', 'spending_flag', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     customer_id spending_flag      loyalty_flag  order_number
# 0             1   Low spender      New customer             1
# 1             1   Low spender      New customer             2
# 2             1   Low spender      New customer             3
# 3             1   Low spender      New customer             4
# 4             1   Low spender      New customer             5
# 5             1   Low spender      New customer             6
# 6             1   Low spender      New customer             7
# 7             1   Low spender      New customer             8
# 8             1   Low spender      New customer             9
# 9             1   Low spender      New customer            10
# 10           15   Low spender  Regular customer            15
# 11           15   Low spender  Regular customer            17
# 12           15   Low spender  Regular customer            18
# 13           15   Low spender  Regular customer            21
# ...

# %%
# create order frequency flag 
ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['customer_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 26)

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
ords_prods_merge = ords_prods_merge.drop(columns = ['median_days_since_previous_order'])

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
# create frequency flag 
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']>20, 'Frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order']>10) & (ords_prods_merge['median_days_since_prior_order']<=20), 'Frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order']<=10, 'Frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
# ...

# %%
# export
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_v4.pkl'))
